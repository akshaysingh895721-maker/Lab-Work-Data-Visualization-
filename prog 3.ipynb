# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Lab-Work-Data-Visualization-/blob/main/prog%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to remove the common element

# take the element
list1 = [1, 2, 3, 4]
list2 = [3, 4, 5]

# Remove common elements
result = []

for item in list1:
    if item not in list2:
        result.append(item)

print("Result:", result)
# Out:
# Result: [1, 2]
