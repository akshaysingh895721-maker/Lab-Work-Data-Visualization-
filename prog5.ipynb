# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Lab-Work-Data-Visualization-/blob/main/prog5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Input list
my_list = [1, 2, 2, 3, 4, 4]

# Remove duplicates using set
unique_list = list(set(my_list))

# Convert to tuple
result_tuple = tuple(unique_list)

print("Result:", result_tuple)
# Out:
# Result: (1, 2, 3, 4)
